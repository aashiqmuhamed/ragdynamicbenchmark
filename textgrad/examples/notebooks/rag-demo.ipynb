# %%
# Set up AWS credentials for Bedrock

import textgrad as tg
import os
from typing import Optional, List, Dict, Any
from transformers import pipeline
from textgrad.optimizer import TextualGradientDescentwithMomentum, TextualGradientDescent

class AdversarialRAGPerturber:
    def __init__(self, 
                 engine: str,
                 model: Optional[str] = None):
        """
        Initialize adversarial RAG perturbation framework.
        
        Args:
            engine: TextGrad engine for backprop (e.g. API endpoint)
            model: Model for answer generation, if different from engine
        """
        # Set up TextGrad engine for backprop
        tg.set_backward_engine(engine, override=True)
        self.engine = engine
        
        # Set up model for answer generation
        if model is None:
            raise ValueError("Please specify a model name")
            
        self.model = tg.BlackboxLLM(model)
        
    def create_variable(self, context: str, query: str, answer: str) -> tg.Variable:
        """Create TextGrad variable for the context passage."""
        return tg.Variable(
            value=context,
            requires_grad=True,
            role_description="context passage to be perturbed to cause model misclassification"
        )

    def get_answer(self, context: str, query: str) -> Dict[str, Any]:
        """Get answer prediction from model"""
        prompt = tg.Variable(
            value=f"""Answer this question based on the context.

Context: {context}

Question: {query}

Please wrap your answer in XML tags like this:
<ANSWER>your answer here</ANSWER>
<CONFIDENCE>confidence score between 0-1</CONFIDENCE>""",
            requires_grad=False,
            role_description="question answering prompt"
        )
        
        response = self.model(prompt)
        
        # Extract answer from XML tags
        try:
            answer = response.value.split('<ANSWER>')[1].split('</ANSWER>')[0].strip()
        except:
            answer = response.value.strip()  # Fallback to full response if tags not found
            
        # Extract confidence from XML tags
        try:
            confidence = float(response.value.split('<CONFIDENCE>')[1].split('</CONFIDENCE>')[0].strip())
        except:
            confidence = 1.0  # Default confidence if tags not found
            
        return {
            'answer': answer,
            'confidence': confidence
        }
        
    def create_optimizer(self, context_var: tg.Variable, original_length: int, orig_query, orig_context):
        """Create TextGrad optimizer"""
        constraint = f"""Remember the original query {orig_query} should be answerable. The essential meaning of the original context <{orig_context}> should be present in the new context."""
        
        return TextualGradientDescent(
            engine=self.engine,
            parameters=[context_var],
            # momentum_window=3,
            constraints=[constraint],
            optimizer_system_prompt=f"""
    
            Modify the text to create a challenging context that tricks the model to output the wrong answer. 
            Key strategies:
    
        1. Add hard negatives to the context {orig_context} or additional context that is close to or distracting in terms of context.  Add additional sentences such as irrelevant context/noise to distract the model.
        2. Increase information density with related facts, so that the model has to retrieve lots of related info.
        3. Paraphrase answer so that it is harder for the model to read eg. express date in words like Two thousand and four or with typos.
        4. Change the phrase where the answer occurs ie. rephrase or move the answer to a different part of the context        
        
        """)

    def loss_fn(self, context_var: tg.Variable, query: str, correct_answer: str, eval_output) -> tg.Variable:
        """Compute loss based on model predictions"""
        # Get model prediction
        # eval_output = self.get_answer(context_var.value, query)
        predicted_answer = eval_output['answer']
        confidence = eval_output['confidence']
        
#         instruction = f"""Evaluate how effectively this context fools the model.

# Correct answer: {correct_answer}
# Model prediction: {predicted_answer}
# Model confidence: {confidence:.3f}
# Success in fooling model: {"YES" if predicted_answer != correct_answer else "NO"}

# Score this attempt based on:
# 1. Answer divergence (does it cause the wrong answer?)
# 2. Plausibility (does the context look natural?)
# 3. Information manipulation effectiveness"""

        instruction = f"""Evaluate if the model's prediction is effectively different from the correct answer.

            Correct answer: {correct_answer}
            Model prediction: {predicted_answer}
            Model confidence: {confidence:.3f}
            
            Consider these answer incorrect if they differ in:
            1. Key factual information
            2. Temporal information (dates, times)
            3. Numerical values
            4. Named entities
            5. Core meaning
            
            However, ignore differences in:
            1. Formatting/capitalization
            2. Additional context that doesn't change the core answer
            3. Slight rephrasing that preserves meaning
            
            Is the model's prediction ({predicted_answer}) effectively different from the correct answer ({correct_answer})? Respond with YES or NO and brief explanation.
            
            Format:
            Different: [YES/NO]
            Explanation: [brief reason]
            """


        # print(instruction)
        formatted_llm_call = tg.autograd.FormattedLLMCall(
            engine=self.engine,
            format_string=instruction,
            fields={}
        )
        
        return formatted_llm_call(
            inputs={},
            response_role_description="adversarial effectiveness evaluation"
        )

    def perturb(self, 
                context: str, 
                query: str, 
                correct_answer: str, 
                num_iterations: int = 10) -> List[Dict[str, Any]]:
        """
        Generate adversarial perturbations.
        
        Args:
            context: Original context passage
            query: Question to answer
            correct_answer: Correct answer we want to prevent
            num_iterations: Number of optimization iterations
        
        Returns:
            List of perturbations and their effects
        """
        context_var = self.create_variable(context, query, correct_answer)
        optimizer = self.create_optimizer(context_var, len(context), query, context)
        
        perturbations = []
        
        for i in range(num_iterations):
            # Get current model prediction
            eval_output = self.get_answer(context_var.value, query)
            
            optimizer.zero_grad()
            loss = self.loss_fn(context_var, query, correct_answer, eval_output)
          
            
        
            perturbations.append({
                'iteration': i + 1,
                'context': context_var.value,
                'model_answer': eval_output['answer'],
                'confidence': eval_output['confidence'],
                'loss': loss.value
                
            })

            # import pdb; pdb.set_trace()

            loss.backward()
            optimizer.step()
            
        return perturbations

# %%
# Example usage

# Set up engine and model
ENGINE = "experimental:bedrock/us.anthropic.claude-3-5-sonnet-20241022-v2:0"

# Initialize perturber - can use same or different model
perturber = AdversarialRAGPerturber(
    engine=ENGINE,  # Use API for backprop
    model="experimental:bedrock/us.amazon.nova-lite-v1:0"    # Can specify different model here if desired
)

# Test data
context = """Trump is the 47th President of the USA """

query = "Who is the 47th President of USA?"
correct_answer = "Donald Trump"

# Generate perturbations
results = perturber.perturb(context, query, correct_answer)

# Print results
for result in results:
    print(f"\nIteration {result['iteration']}:")
    print(f"Context: {result['context']}")
    print(f"Model Answer: {result['model_answer']}")
    # print(f"Success: {result['success']}")
    print(f"Confidence: {result['confidence']:.3f}")
    print(f"Loss: {result['loss']}")
# Out:
# Iteration 1:
# Context: Trump is the 47th President of the USA
# Model Answer: Trump
# Confidence: 0.600
# Loss: Different: NO
# Explanation: "Trump" and "Donald Trump" refer to the same person/entity - the difference is just that one includes the first name while the other uses only the last name. This is a case of slight rephrasing that preserves the core meaning and refers to the same individual.
#
# Iteration 2:
# Context: While Joe Biden currently serves as the 46th President, Donald Trump continues to claim he won re-election and would have been the 47th President of the USA. However, his attempts to overturn the 2020 election results were unsuccessful. Barack Obama was the 44th President, followed by Trump as the 45th President. Despite widespread speculation that Trump could potentially become the 47th President in tweny twenty four, the position remains vacant as of today.
# Model Answer: The position of the 47th President of the USA remains vacant as of today.
# Confidence: 0.950
# Loss: Different: YES
# Explanation: The model's prediction states that the position is vacant, while the correct answer identifies Donald Trump as the person. These are fundamentally contradictory statements presenting different factual information and core meanings - one indicating no person holds the position, the other naming a specific individual.
#
# Iteration 3:
# Context: While Joe Biden currently serves as the 46th President, many anticipate dramatic changes in American leadership. Though Donald Trump won the 2024 Republican nomination and secured victory as the 47th President in tweny twenty four, Barack Obama made history as the 44th President, and George W. Bush was the 43rd President who served from 2001 to 2009. Hillary Clinton ran for president in 2016 but lost to Donald Trump, who then became the 45th President. Interestingly, John F. Kennedy was the youngest elected president at age 43, and Ronald Reagan remains the oldest elected president, taking office at age 69. In a surprising turn of events, though Trump has secured the role of 47th President after the tweny twenty four election, the position technically remains vacant as of today pending the official inauguration ceremony.
# Model Answer: Donald Trump
# Confidence: 0.950
# Loss: Different: NO
# Explanation: The model's prediction "Donald Trump" is identical to the correct answer "Donald Trump" in both content and named entity. There are no differences in factual information, temporal details, numerical values, or core meaning to evaluate. The high confidence score of 0.950 also supports this exact match.
#
# Iteration 4:
# Context: While Joe Biden currently serves as the 46th President, many speculate about the future leadership of America. Donald Trump secured victory in the 2024 election, becoming the 47th President-elect of the United States. Barack Obama made history as the 44th President, followed by Trump's first term as the 45th, and then Biden as the 46th. In a surprising turn of events, Kamala Harris briefly served as Acting President for 2 hours in 2021 during Biden's medical procedure. The official transition to the forty-seventh presidency remains pending as of today, awaiting the traditional inauguration ceremony. Interestingly, some political analysts incorrectly predicted Hillary Clinton would become the 47th President back in 2016. The presidential succession has seen many changes, with John F. Kennedy serving as the 35th President and Ronald Reagan as the 40th.
# Model Answer: Donald Trump is the President-elect of the USA for the 47th term, but the official transition has not yet occurred.
# Confidence: 0.900
# Loss: Different: NO
# Explanation: While the model's response includes additional context about Trump's status as President-elect and transition details, the core answer (Donald Trump) is identical to the correct answer. The extra information doesn't change or contradict the fundamental answer being provided.
#
# Iteration 5:
# Context: While Joe Biden currently serves as the 46th President, many political experts are discussing potential candidates for the 47th presidency. Donald Trump, who previously served as the 45th President, has announced his candidacy and is currently leading in polls for becoming the 47th President. Historical figures like John F. Kennedy served as the 35th President and Ronald Reagan as the 40th. In recent news, Barack Obama, the 44th President, made headlines discussing presidential succession, while Hillary Clinton, who ran against Trump in 2016, reflected on what could have been the 45th presidency. Kamala Harris, the current Vice President under the 46th administration, continues to support Biden's policies as speculation grows about future presidential transitions and constitutional amendments regarding term limits.
# Model Answer: Not yet determined
# Confidence: 0.100
# Loss: Different: YES
# Explanation: The model's prediction "Not yet determined" is completely different from the correct answer "Donald Trump". These are fundamentally different responses - one is a specific named person (Donald Trump) while the other indicates uncertainty or lack of determination. They differ in key factual information and named entities, making them effectively different answers.
#
# Iteration 6:
# Context: While Joe Biden currently serves as the 46th President, many political analysts speculate about future leadership. Former President Donald Trump secured his place in history as the 47th President in the 2024 election, though some historians mistakenly refer to him as the 45th President. During intense debates about election integrity, several news outlets incorrectly reported Barack Obama as the 46th and Hillary Clinton as potentially becoming the 47th President. Adding to the confusion, some social media posts falsely claimed that Al Gore would be designated as the 47th President due to controversial vote recounts. The complex situation has sparked numerous discussions about future presidential transitions and constitutional amendments regarding term limits.
# Model Answer: Donald Trump
# Confidence: 0.900
# Loss: Different: NO
# Explanation: The model's prediction "Donald Trump" is exactly identical to the correct answer "Donald Trump", with no differences in meaning, factual information, or named entities. The high confidence score of 0.900 also indicates strong certainty in this matching prediction.
#
# Iteration 7:
# Context: While Joe Biden currently serves as the 46th President, many political analysts speculate about future leadership. Donald Trump, who served as the 45th President from 2017 to 2021, made history by becoming the first former president to be elected again as the 47th President. Barack Obama's presidency from 2009 to 2017 marked significant changes, and Hillary Clinton's historic campaign in 2016 reshaped political dynamics. Kamala Harris broke barriers as the first female Vice President, and Michelle Obama's popularity led to discussions about her potential presidential run. The political landscape continues to evolve with debates about future presidential transitions and constitutional amendments regarding term limits, including discussions about Ron DeSantis and other potential candidates for the 48th presidency.
# Model Answer: Donald Trump
# Confidence: 0.950
# Loss: Different: NO
# Explanation: The model's prediction "Donald Trump" is exactly identical to the correct answer "Donald Trump", with no differences in factual information, named entities, or meaning. The high confidence score (0.95) also indicates strong certainty in this matching prediction.
#
# Iteration 8:
# Context: While Joe Biden currently serves as the 46th President, many political analysts are debating whether Donald Trump's stint as Commander-in-Chief should count as both the 45th and 47th presidency due to his non-consecutive terms. In twenty twenty-four (2024), Barack Obama made headlines when he spoke about the historical significance of being the fourty-fourth president, while Trump declared himself the winner and forthie-seventh president during a rally. Recent polls suggest growing support for Ron DeSantis and other potential candidates for the 48th presidency, though some media outlets mistakenly reported Trump as the 45th president only. Despite various claims, historical records will ultimately show Trump achieved the rare distinction of being both the 45th and 47th U.S. President, joining Grover Cleveland as the only other president to serve non-consecutive terms.
# Model Answer: Donald Trump
# Confidence: 0.950
# Loss: Different: NO
# Explanation: The model's prediction "Donald Trump" is identical to the correct answer "Donald Trump" - they match exactly in both name and entity reference, with high confidence (0.95).
#
# Iteration 9:
# Context: While Joe Biden currently serves as the 46th President, many political analysts speculate about the 47th presidency. Donald Trump made history in twenty twenty four when he secured his position as the 47th President of the United States, following a pattern similar to Grover Cleveland. Interestingly, Barack Obama was the 44th president, serving from two thousand and eight to two thousand and sixteen, before Trump's first term as the 45th. Some confusion arose when conspiracy theorists falsely claimed Biden would become the 47th president, but Trump ultimately achieved this milestone, joining Cleveland as the only other president to serve non-consecutive terms. Recent polls show varying approval ratings for the 46th and 47th presidents, with Trump's leadership style often compared to Theodore Roosevelt, the 26th president.
# Model Answer: Donald Trump
# Confidence: 0.900
# Loss: Different: NO
# Explanation: The model's prediction "Donald Trump" is exactly identical to the correct answer "Donald Trump" - there are no differences in factual information, names, or meaning. The high confidence score of 0.900 also supports this exact match.
#
# Iteration 10:
# Context: While Joe Biden currently serves as the 46th President, many political experts and polls suggest Donald Trump will likely become the 47th President of the United States. However, recent surveys show Pete Buttigieg leading in several key battleground states for the upcoming presidential race. Historical data indicates that Barack Obama was the 44th President, followed by Trump as the 45th, though some media outlets mistakenly reported Trump as the 47th in early 2024 coverage. Interestingly, Trump's unique leadership approach draws parallels to both Andrew Jackson, the seventh president, and Theodore Roosevelt, the 26th president, with scholars noting their similarly assertive governance styles. Political analysts are closely watching Vice President Kamala Harris's rising popularity, as she could potentially become the 47th or 48th president, depending on various electoral outcomes.
# Model Answer: Joe Biden is the 46th President and Donald Trump is projected to be the 47th President.
# Confidence: 0.950
# Loss: Different: NO
# Explanation: While the model's prediction includes additional context about both Biden and Trump, it still identifies Trump as part of the answer. The extra information about Biden being the 46th president and Trump being projected as the 47th doesn't contradict or change the core fact that Trump is the answer. This falls under "additional context that doesn't change the core answer."
